# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread('dspcd.jpg')

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
biru = img[:, :, 0]
hijau = img[:, :, 1]
merah = img[:, :, 2]

# %% [markdown]
# plt.figure(figsize=(15, 5))
# # Tampilkan gambar asli
# plt.subplot(2, 2, 1)
# plt.imshow(img)
# plt.title('Citra Asli')
# plt.axis('off')
#
# # Tampilkan saluran warna biru
# plt.subplot(2, 2, 2)
# plt.imshow(biru, cmap='gray')
# plt.title('Saluran Biru')
# plt.axis('off')
#
# # Tampilkan saluran warna hijau
# plt.subplot(2, 2, 3)
# plt.imshow(hijau, cmap='gray')
# plt.title('Saluran Hijau')
# plt.axis('off')
#
# # Tampilkan saluran warna merah
# plt.subplot(2, 2, 4)
# plt.imshow(merah, cmap='gray')
# plt.title('Saluran Merah')
# plt.axis('off')
#
# # Tampilkan gambar
# plt.tight_layout()
# plt.show()

# %%
fig, axs = plt.subplots(2,2, figsize=(20,6))
axs[0, 0].hist(img.ravel(),256,[0,256])
axs[0, 0].set_title('Histogram Citra Asli')

axs[0, 1].hist(biru.ravel(), 256, [0, 256], color='blue')
axs[0, 1].set_title('Histogram Saluran Biru')

axs[1, 0].hist(hijau.ravel(), 256, [0, 256], color='green')
axs[1, 0].set_title('Histogram Saluran Hijau')

axs[1, 1].hist(merah.ravel(), 256, [0, 256], color='red')
axs[1, 1].set_title('Histogram Saluran Merah')

plt.show()

# %%
# Baca gambar
gambar = cv2.imread('dspcd.jpg')

# Konversi gambar ke ruang warna HSV
hsv = cv2.cvtColor(gambar, cv2.COLOR_BGR2HSV)

# Definisikan rentang warna untuk biru, merah, dan hijau
biru_bawah = np.array([100, 43, 46])
biru_atas = np.array([130, 255, 255])

merah_bawah = np.array([160, 43, 46])
merah_atas = np.array([180, 255, 255])

hijau_bawah = np.array([36, 43, 46])
hijau_atas = np.array([70, 255, 255])

# Buat masker untuk setiap warna
biru_mask = cv2.inRange(hsv, biru_bawah, biru_atas)
merah_mask = cv2.inRange(hsv, merah_bawah, merah_atas)
hijau_mask = cv2.inRange(hsv, hijau_bawah, hijau_atas)

# Temukan piksel yang cocok dengan setiap warna
biru_piksel = cv2.bitwise_and(gambar, gambar, mask=biru_mask)
merah_piksel = cv2.bitwise_and(gambar, gambar, mask=merah_mask)
hijau_piksel = cv2.bitwise_and(gambar, gambar, mask=hijau_mask)

# Tampilkan gambar asli dan gambar yang dideteksi menggunakan matplotlib
plt.figure(figsize=(10, 5))

# Gambar Asli
plt.subplot(2, 2, 1)
plt.imshow(cv2.cvtColor(gambar, cv2.COLOR_BGR2RGB))
plt.title('Gambar Asli')
plt.axis('off')

# Gambar Biru
plt.subplot(2, 2, 2)
plt.imshow(cv2.cvtColor(biru_piksel, cv2.COLOR_BGR2RGB))
plt.title('Biru')
plt.axis('off')

# Gambar Merah
plt.subplot(2, 2, 3)
plt.imshow(cv2.cvtColor(merah_piksel, cv2.COLOR_BGR2RGB))
plt.title('Merah')
plt.axis('off')

# Gambar Hijau
plt.subplot(2, 2, 4)
plt.imshow(cv2.cvtColor(hijau_piksel, cv2.COLOR_BGR2RGB))
plt.title('Hijau')
plt.axis('off')

plt.tight_layout()
plt.show()
